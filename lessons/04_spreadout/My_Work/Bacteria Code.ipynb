# %% [markdown]
# # Module 4 Final Code

# %%
import numpy as np
uvinitial = np.load('uvinitial.npz')
U = uvinitial['U']
V = uvinitial['V']

# %%
#GIVENS
n = 192
Du, Dv, F, k = 0.00016, 0.00008, 0.035, 0.065 # Bacteria 1 
dh = 5./(n-1)
T = 8000
dt = .9 * dh**2 / (4*max(Du,Dv))
nt = int(T/dt)

# %%
x = np.linspace(0.0,5.0,n)
y = np.linspace(0.0,5.0,n)

X,Y = np.meshgrid(x,y)

# %%
plt.figure
plt.contour(X,Y,U.T)
# Out:
# <matplotlib.contour.QuadContourSet instance at 0x66688c0>

# %%
plt.figure
plt.contour(X,Y,V.T)
# Out:
# <matplotlib.contour.QuadContourSet instance at 0x6e61200>

# %%
for tstep in range(nt):
    un=U.copy()
    vn=V.copy()
    
    U[1:-1,1:-1]=un[1:-1,1:-1]+dt*(Du*(un[:-2,1:-1]+un[2:,1:-1]-2*un[1:-1,1:-1])/(dh*dh)+\
                 Du*(un[1:-1,:-2]+un[1:-1,2:]-2*un[1:-1,1:-1])/(dh*dh)+\
                 -(un[1:-1,1:-1]*vn[1:-1,1:-1]*vn[1:-1,1:-1])+F*(1-un[1:-1,1:-1]))

    V[1:-1,1:-1]=vn[1:-1,1:-1]+dt*(Dv*(vn[:-2,1:-1]+vn[2:,1:-1]-2*vn[1:-1,1:-1])/(dh*dh)+\
                 Dv*(vn[1:-1,:-2]+vn[1:-1,2:]-2*vn[1:-1,1:-1])/(dh*dh)+\
                 +un[1:-1,1:-1]*vn[1:-1,1:-1]*vn[1:-1,1:-1]-(F+k)*(vn[1:-1,1:-1]))
    
    
    U[0,:]=U[1,:]
    U[-1,:]=U[-2,:]
    U[:,0]=U[:,1]
    U[:,-1]=U[:,-2]
    
    V[0,:]=V[1,:]
    V[-1,:]=V[-2,:]
    V[:,0]=V[:,1]
    V[:,-1]=V[:,-2]

# %%
plt.figure
plt.contour(X,Y,U.T)
# Out:
# <matplotlib.contour.QuadContourSet instance at 0x77ca4d0>

# %%
plt.figure
plt.contour(X,Y,V.T)
# Out:
# <matplotlib.contour.QuadContourSet instance at 0x7a3dcf8>

# %%
print U[100,::40]
# Out:
# [ 0.92469521  0.85013834  0.66815621  0.90196481  0.9039502 ]
